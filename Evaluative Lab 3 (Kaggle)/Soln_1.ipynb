# %%
import matplotlib.pyplot as plt  
import pandas as pd  
# %matplotlib inline
import numpy as np
import io

from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

# %%
test = pd.read_csv('test.csv')

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)      ?                  6
# 1        Caucasian  Female  [10-20)      ?                  1
# 2  AfricanAmerican  Female  [20-30)      ?                  1
# 3        Caucasian    Male  [30-40)      ?                  1
# 4        Caucasian    Male  [40-50)      ?                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1          ?
# 1                         1                    7                 3          ?
# 2                         1                    7                 2          ?
# 3                         1                    7                 2          ?
# 4                         1                    7                 1          ?
#
#           medical_specialty      ...        citoglipton  insulin  \
# ...

# %%
data = df.sample(frac = 0.25)
data.head()
# Out:
#                   race  gender      age weight  admission_type_id  \
# 8563         Caucasian  Female  [40-50)      ?                  5
# 31453        Caucasian    Male  [80-90)      ?                  1
# 2223         Caucasian  Female  [60-70)      ?                  6
# 33696  AfricanAmerican  Female  [50-60)      ?                  1
# 62594        Caucasian  Female  [60-70)      ?                  3
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# 8563                          7                   17                 1
# 31453                         1                    7                 1
# 2223                          1                    7                 3
# 33696                         1                    7                 4
# 62594                         1                    1                 1
#
#       payer_code       medical_specialty      ...        citoglipton  insulin  \
# ...

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
X_2 = data.apply(le.fit_transform)
X_2.head()
# Out:
#        race  gender  age  weight  admission_type_id  discharge_disposition_id  \
# 8563      3       0    4       1                  4                         6
# 31453     3       1    8       1                  0                         0
# 2223      3       0    6       1                  5                         0
# 33696     1       0    5       1                  0                         0
# 62594     3       0    6       1                  2                         0
#
#        admission_source_id  time_in_hospital  payer_code  medical_specialty  \
# 8563                     9                 0           0                  8
# 31453                    6                 0           0                 15
# 2223                     6                 2           0                  0
# 33696                    6                 3           0                 15
# 62594                    0                 0           7                 17
#
# ...

# %%
X = X_2.drop(['readmitted_NO'],axis =1)
y = X_2['readmitted_NO']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state= 0)

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward').fit(X)

# %%
dbsc = DBSCAN(eps = .5, min_samples = 15).fit(X)

# %%
y_pred2 = dbsc.fit_predict()
y_pred2

# %%
t2 = test.apply(le.fit_transform)
t2.head()
# Out:
#    race  gender  age  weight  admission_type_id  discharge_disposition_id  \
# 0     3       0    8       1                  1                         2
# 1     3       0    4       1                  0                         0
# 2     3       1    5       1                  2                         0
# 3     3       0    5       1                  0                         0
# 4     3       1    8       1                  1                         2
#
#    admission_source_id  time_in_hospital  payer_code  medical_specialty  \
# 0                    6                 5           8                  4
# 1                    6                 1           4                  0
# 2                    0                 0           4                  0
# 3                    6                 2           7                  7
# 4                    6                 4           8                  4
#
#    ...    citoglipton  insulin  glyburide-metformin  glipizide-metformin  \
# ...

# %%
y_pred = cluster.fit_predict(t2)
y_pred

# %%
from sklearn.metrics import accuracy_score

s = accuracy_score(y_test, y_pred)
s
# Out:
# 0.4850280723643169

# %%
sample = pd.read_csv('sample_sub.csv')
sample.dtypes
# Out:
# index     int64
# target    int64
# dtype: object

# %%
df_soln = pd.DataFrame(data = [test['index'], y_pred], index = None)
df = df_soln.transpose()
df['index'] = df['index'].astype(int)
df.columns = ['soldierId','bestSoldierPerc']
df['target'] = df['target'].astype(int)
df.to_csv('soln 1.csv',index = False)

# %%
from sklearn.metrics import accuracy_score

x = accuracy_score(y_test, y_pred)
