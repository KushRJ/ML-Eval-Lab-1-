# %%
import matplotlib.pyplot as plt  
import pandas as pd  
# %matplotlib inline
import numpy as np

from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('train.csv')

# %%
data.describe()
# Out:
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# count       71236.000000              71236.000000         71236.000000
# mean            2.152297                  3.997235             5.881745
# std             1.546621                  5.686334             4.426288
# min             1.000000                  1.000000             1.000000
# 25%             1.000000                  1.000000             1.000000
# 50%             2.000000                  1.000000             7.000000
# 75%             3.000000                  5.000000             7.000000
# max             8.000000                 28.000000            22.000000
#
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count      71236.000000        71236.000000    71236.000000     71236.000000
# mean           4.491479           43.129934        1.344601        15.719987
# std            3.038481           19.006543        1.681742         8.174863
# ...

# %%
data.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)      ?                  6
# 1        Caucasian  Female  [10-20)      ?                  1
# 2  AfricanAmerican  Female  [20-30)      ?                  1
# 3        Caucasian    Male  [30-40)      ?                  1
# 4        Caucasian    Male  [40-50)      ?                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1          ?
# 1                         1                    7                 3          ?
# 2                         1                    7                 2          ?
# 3                         1                    7                 2          ?
# 4                         1                    7                 1          ?
#
#           medical_specialty      ...        citoglipton  insulin  \
# ...

# %%
X = data.columns['admission_type_id','discharge_disposition_id','admission_source_id','time_in_hospital','num_lab_procedures',
         'num_procedures','num_medications','number_outpatient','number_emergency','number_inpatient','number_diagnoses']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-e97a16e0c86d> in <module>()
#       1 X = data.columns['admission_type_id','discharge_disposition_id','admission_source_id','time_in_hospital','num_lab_procedures',
# ----> 2          'num_procedures','num_medications','number_outpatient','number_emergency','number_inpatient','number_diagnoses']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    1698
#    1699         key = _values_from_object(key)
# -> 1700         result = getitem(key)
#    1701         if not is_scalar(result):
#    1702             return promote(result)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=5, affinity='levenshtein', linkage='ward')  
cluster.fit_predict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-bf6fd2466520> in <module>()
#       2
#       3 cluster = AgglomerativeClustering(n_clusters=5, affinity='levenshtein', linkage='ward')
# ----> 4 cluster.fit_predict(data)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     408         # non-optimized default implementation; override when a better
#     409         # method is possible for a given clustering algorithm
# --> 410         self.fit(X)
#     411         return self.labels_
#     412
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in fit(self, X, y)
#     694         self
#     695         """
# --> 696         X = check_array(X, ensure_min_samples=2, estimator=self)
#     697         memory = check_memory(self.memory)
#     698
#
# ...
